                       'IBk': [95.14102206087685, 95.21083496230104, 91.32923764311644, 96.27199106394862, 95.09913432002234, 93.5213627478358, 95.22413070800168, 93.10152213378021, 87.06884513336126], 
                       'REPTree': [97.73806199385646, 95.3504607651494, 95.68556269198548, 99.83244903658196, 95.42027366657358, 97.94750069812902, 97.48638458315878, 91.25820416142997, 81.42717497556208], 
                       'SMO': [95.51801172856744, 95.00139625802848, 72.32616587545378, 97.62636135157777, 95.02932141859816, 95.6157497905613, 96.8859097891356, 95.4335986594051, 63.510682865521574], 
                       'Multi': [96.23010332309411, 97.65428651214745, 95.96425080296048]}

regression_data = {'Logistic': [3154.7894500521134, 14879.842151054801, 4000.9720464034654, 2893.259134095088, 8434.587032054244, 3373.118180368074, 2796.1538044854956, 35179.033196281154, 4425.8135084698615], 
                   'NaiveBayes': [3986.109525993479, 22799.83469168629, 27783.418978804835, 4966.5036865121265, 27337.891890398772, 28029.35050031271, 4914.443088484286, 46871.2704671569, 27968.528183649705], 
                   'IBk': [4002.3244173095545, 6745.935430361077, 6739.535154903416, 3560.193786184139, 6829.3256596777865, 3638.477422636881, 4175.9898136665215, 31876.53683369603, 10113.432832772613], 
                   'REPTree': [5029.45209566256, 9073.98919487531, 4738.692659822239, 1104.8713900363082, 5625.04396830818, 1950.8121726386403, 4125.749538604484, 29675.887940674784, 11890.712830671688], 
                   'SMO': [1814.3610510430117, 4823.655863957225, 6762.025972780191, 4029.688707263961, 4731.619628987005, 5064.467765980831, 4209.908144464417, 31984.644420894456, 10019.275941825843], 
                   'Multi': [2526.1894694189855, 4843.974834728321, 10947.591031628508]}

# %%
box_1, box_2, box_3, box_4, box_5, box_6 = classification_data['Logistic'], classification_data['NaiveBayes'], classification_data['IBk'], classification_data['REPTree'], classification_data['SMO'], classification_data['Multi']

# plt.title('Classfication Result',fontsize=20)#标题，并设定字号大小
labels = 'LR','NB','KNN','DT','SVM',"MSAP"  #图例
 
#vert=False:水平箱线图；showmeans=True：显示均值
plt.rcParams['font.size'] = 18
plt.boxplot([box_1, box_2, box_3, box_4, box_5, box_6], labels = labels, vert=True,showmeans=True)
plt.ylabel('Accuracy(%)')#设置y轴标签
plt.xlabel('Classfication Model')#设置y轴标签
# plt.xticks(rotation=45)
plt.savefig('cls_same.pdf', bbox_inches = 'tight')

# %%
box_1, box_2, box_3, box_4, box_5, box_6 = regression_data['Logistic'], regression_data['NaiveBayes'], regression_data['IBk'], regression_data['REPTree'], regression_data['SMO'], regression_data['Multi']

# plt.title('Classfication Result',fontsize=20)#标题，并设定字号大小
labels = 'LR','SVM','KNN','DT','MLP',"MSAP"  #图例
 
#vert=False:水平箱线图；showmeans=True：显示均值
plt.boxplot([box_1, box_2, box_3, box_4, box_5, box_6], labels = labels, vert=True,showmeans=True)
plt.ylabel('RMSE')#设置y轴标签
plt.xlabel('Regression Model')#设置y轴标签
# plt.xticks(rotation=45)
plt.savefig('reg_same.pdf', bbox_inches = 'tight')

# %%
# classification_data = {
#     "pgfault": [66.21, 31.028, 87.421, 95.001, 95.006, 95.001, 95.001, 87.782, 97.313, 99.888, 99.691, 99.534, 95.001, 95.006, 97.763],
#     "mem_shared": [86.121, 61.453, 18.598, 95.001, 95.006, 95.001, 85.297, 76.770, 89.087, 79.447, 76.223, 95.166, 57.665, 96.465, 90.513],
#     "slab": [5.012, 50.554, 91.188, 95.001, 95.020, 95.016, 95.001, 82.381, 96.067, 96.299, 95.385, 96.697, 97.877, 72.604, 97.373],
#     "Multi":[98.548, 98.246, 96.6677]
# }

# regression_data = {
#     "pgfault": [2810, 1531, 722, 1524, 5679, 484, 13007, 13139, 4295, 9805, 5088, 803, 963, 9113, 1084],
#     "mem_shared": [22011, 30610, 9465, 40644, 36340, 5866, 22696, 26449, 3266, 14474, 19256, 565, 13278, 21096, 5425],
#     "slab": [6158, 5048, 2346, 3617, 3199, 2338, 13171, 10794, 4925, 2535, 7019, 1801, 4168, 8875, 2440],
#     "Multi":[5469.9521, 8232.9, 818.7]
# }

def regroup_data_by_metric(origin_data, num):
    new_list = []
    for i in range(num, 9, 3):
        new_list += [origin_data[key][i] for key in origin_data if key != 'Multi']
    return new_list

classification_data_by_metric = {
    "pgfault": regroup_data_by_metric(classification_data, 0),
    "mem_shared": regroup_data_by_metric(classification_data, 1),
    "slab": regroup_data_by_metric(classification_data, 2),
    "Multi": classification_data['Multi']
}

regression_data_by_metric = {
    "pgfault": regroup_data_by_metric(regression_data, 0),
    "mem_shared": regroup_data_by_metric(regression_data, 1),
    "slab": regroup_data_by_metric(regression_data, 2),
    "Multi": regression_data['Multi']
}

print(classification_data_by_metric)

box_1, box_2, box_3, box_4 = classification_data_by_metric['pgfault'], classification_data_by_metric['mem_shared'], classification_data_by_metric['slab'], classification_data_by_metric['Multi']

# plt.title('Classfication Result',fontsize=20)#标题，并设定字号大小
labels = 'Page Faults','Memory Shared','Slab','MSAP'  #图例
 
#vert=False:水平箱线图；showmeans=True：显示均值
plt.boxplot([box_1, box_2, box_3, box_4], labels = labels, vert=True,showmeans=True)
plt.ylabel('Accuracy(%)')#设置y轴标签
plt.xlabel('Metric')#设置y轴标签
plt.xticks(rotation=45)
plt.savefig('cls_metric.pdf', bbox_inches = 'tight')
# Out:
# {'pgfault': [89.26277576096062, 98.75733035464954, 95.14102206087685, 97.73806199385646, 95.51801172856744, 90.03071767662664, 98.7014800335102, 96.27199106394862, 99.83244903658196, 97.62636135157777, 93.47856444630638, 96.31336405529954, 95.22413070800168, 97.48638458315878, 96.8859097891356], 'mem_shared': [56.35297402960067, 85.18570231778833, 95.21083496230104, 95.3504607651494, 95.00139625802848, 66.55962021781625, 92.66964535046075, 95.09913432002234, 95.42027366657358, 95.02932141859816, 95.00069822650468, 77.85225527161012, 93.10152213378021, 91.25820416142997, 95.4335986594051], 'slab': [61.04440100530578, 92.15302987992182, 91.32923764311644, 95.68556269198548, 72.32616587545378, 41.92962859536442, 88.4110583635856, 93.5213627478358, 97.94750069812902, 95.6157497905613, 46.781175813433876, 91.63524647395616, 87.06884513336126, 81.42717497556208, 63.510682865521574], 'Multi': [96.23010332309411, 97.65428651214745, 95.96425080296048]}

# %%
box_1, box_2, box_3, box_4 = regression_data_by_metric['pgfault'], regression_data_by_metric['mem_shared'], regression_data_by_metric['slab'], regression_data_by_metric['Multi']

# plt.title('Classfication Result',fontsize=20)#标题，并设定字号大小
labels = 'Page Faults','Memory Shared','Slab','MSAP'  #图例
 
#vert=False:水平箱线图；showmeans=True：显示均值
plt.boxplot([box_1, box_2, box_3, box_4], labels = labels, vert=True,showmeans=True)
plt.ylabel('RMSE')#设置y轴标签
plt.xlabel('Metric')#设置y轴标签
plt.xticks(rotation=45)
plt.savefig('reg_metric.pdf', bbox_inches = 'tight')

# %%
import statistics

data = [99.690,
94.225,
99.620,
99.901,
98.819]
print(f'{statistics.mean(data):.3f}±{statistics.stdev(data):.3f}')
# Out:
# 98.451±2.398
